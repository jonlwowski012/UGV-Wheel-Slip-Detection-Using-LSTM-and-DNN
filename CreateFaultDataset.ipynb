# %%
import csv
import pandas as pd
import numpy as np
from numpy import genfromtxt

# %%
df = pd.read_csv('time.csv')

# %%
time = genfromtxt('time.csv', delimiter=',')
vleft = genfromtxt('vleft.csv', delimiter=',')
vleft_labels = genfromtxt('vleft_faultlabel.csv', delimiter=',')
vright = genfromtxt('vright.csv', delimiter=',')
vright_labels = genfromtxt('vright_faultlabel.csv', delimiter=',')
vx = genfromtxt('vx.csv', delimiter=',')
vw = genfromtxt('vw.csv', delimiter=',')
labels = np.logical_or(vleft_labels,vright_labels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-f3137c7e7c7c> in <module>()
# ----> 1 time = np.float(genfromtxt('time.csv', delimiter=','))
#       2 vleft = genfromtxt('vleft.csv', delimiter=',')
#       3 vleft_labels = genfromtxt('vleft_faultlabel.csv', delimiter=',')
#       4 vright = genfromtxt('vright.csv', delimiter=',')
#       5 vright_labels = genfromtxt('vright_faultlabel.csv', delimiter=',')
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
df = pd.DataFrame({'time':time,'vleft':vleft,'vright':vright,'vx':vx,'vw':vw,''})

# %%
df
# Out:
#        time   vleft  vright
# 0     0.000  4.8810  5.0725
# 1     0.005  5.0349  4.8936
# 2     0.010  4.9298  4.9110
# 3     0.015  4.7634  4.8277
# 4     0.020  5.0002  4.9438
# 5     0.025  5.1635  5.1979
# 6     0.030  4.8795  5.1939
# 7     0.035  4.7729  4.9468
# 8     0.040  4.8732  5.0877
# 9     0.045  5.0804  4.8761
# 10    0.050  4.9147  5.2250
# 11    0.055  5.2269  5.0623
# 12    0.060  4.7565  4.8535
# 13    0.065  5.1090  4.8048
# 14    0.070  4.9456  5.0329
# 15    0.075  4.7668  4.8872
# 16    0.080  4.9530  4.7856
# 17    0.085  5.1082  4.8292
# 18    0.090  5.2107  4.7748
# 19    0.095  5.2420  5.0904
# 20    0.100  5.2417  5.1409
# 21    0.105  5.1982  5.1537
# 22    0.110  5.1829  4.8825
# 23    0.115  5.1505  5.1979
# 24    0.120  5.0275  5.0540
# 25    0.125  4.9594  4.7572
# 26    0.130  4.8136  4.9220
# 27    0.135  5.0773  5.0168
# 28    0.140  5.1820  5.0639
# 29    0.145  4.8873  4.9734
# ...     ...     ...     ...
# 1970  9.850  4.9705  5.0440
# ...
